# %%
import glob
import pandas as pd

# %%
path =r'./query_log'
allFiles = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_ = []
for file_ in allFiles:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_,names = ["fid", "cid", "time", "pid"])

# %%
frame.drop(['cid','pid'])
df = frame.sort_values(['fid', 'time'], ascending=[True, True])
